# %%
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

x= stats.norm.rvs(size=1000)
sns.set_style('whitegrid')
sns.kdeplot(np.array(x), bw=0.5)

# %%
y= stats.norm.rvs(size=3000)
sns.set_style('whitegrid')
sns.kdeplot(np.array(y), bw=0.5)

# %%
stats.kstest(x, 'norm')
# Out:
# KstestResult(statistic=0.05360762979187522, pvalue=0.006142198901344615)

# %%
stats.kstest(y, 'norm')
# Out:
# KstestResult(statistic=0.021807835109869778, pvalue=0.11359043725885021)
